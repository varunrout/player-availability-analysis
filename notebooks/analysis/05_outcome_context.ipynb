# %% [markdown]
# # Stage 5 - Descriptive Outcome-Context Analysis
#
# Retrospective pre-onset trajectories and matched same-player references. This notebook does not persist generated outputs or fit a predictive model.

# %%
from IPython.display import display

from player_availability.analysis import build_stage_05_figures, load_stage_05_from_gcp
from player_availability.config import get_settings

# %%
settings = get_settings()
result = load_stage_05_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
)
result.summary

# %% [markdown]
# ## Event, reference and descriptive-difference evidence

# %%
display(result.tables["event_window_audit"])
display(result.tables["matched_difference_summary"])
display(result.tables["team_difference_summary"])
display(result.tables["sensitivity_summary"])
display(result.tables["outcome_context_findings"])

# %% [markdown]
# ## Pre-onset context figures

# %%
figures = build_stage_05_figures(result)
for figure in figures.values():
    display(figure)
