# %% [markdown]
# # Stage 4 - Feature Redundancy and Structural Relationships
#
# Target-blind correlation, coupling and feature-contract evidence. This notebook does not persist generated outputs.

# %%
from IPython.display import display

from player_availability.analysis import build_stage_04_figures, load_stage_04_from_gcp
from player_availability.config import get_settings

# %%
settings = get_settings()
result = load_stage_04_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
)
result.summary

# %% [markdown]
# ## Structural evidence and target-blind contracts

# %%
display(result.tables["high_correlation_pairs"])
display(result.tables["load_coupling_summary"])
display(result.tables["rolling_window_redundancy"])
display(result.tables["full_candidate_contract"])
display(result.tables["operational_feature_family_contract"])
display(result.tables["structural_findings"])

# %% [markdown]
# ## Redundancy and coupling figures

# %%
figures = build_stage_04_figures(result)
for figure in figures.values():
    display(figure)
