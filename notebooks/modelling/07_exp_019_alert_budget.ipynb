# %% [markdown]
# # EXP-019: Alert-Budget Simulation
#
# Development-only translation of raw F1 champion probabilities (`DEC-058`, `DEC-059`) into review-workflow operating points, on pooled rolling-origin predictions. Top 1, 3 and 5 players per team-day are the product-facing primary view (`DEC-060`); the frozen 1%, 2.5% and 5% review rates remain the `DEC-036` comparison basis and are reported alongside it from the same prediction set. A 5%/10%/20% capacity sensitivity is retained but is never a headline. Final-test performance remains locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_exp_019_figures,
    load_exp_019_config,
    load_exp_019_from_gcp,
)

# %%
config = load_exp_019_config(Path("../../configs/modelling/subjective_v1_exp_019_alert_budget.yaml"))
settings = get_settings()
result = load_exp_019_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["alert_budget_results"])
display(result.tables["per_fold_metrics"])
display(result.tables["alert_persistence"])

# %%
display(result.tables["event_capture_detail"])
display(result.tables["one_day_gap_sensitivity"])
display(result.tables["dropped_fold_register"])
display(result.tables["alert_findings"])

# %%
figures = build_exp_019_figures(result)
for figure in figures.values():
    display(figure)
