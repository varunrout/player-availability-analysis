# %% [markdown]
# # EXP-003: M1 Cumulative Feature Ladder
#
# Development-only F1/F2/F3 comparison under the frozen model and validation protocol. Calibration selection and final-test performance remain locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_m1_feature_ladder_figures,
    load_m1_feature_ladder_config,
    load_m1_feature_ladder_from_gcp,
)

# %%
config = load_m1_feature_ladder_config(Path("../../configs/modelling/subjective_v1_m1_feature_ladder.yaml"))
settings = get_settings()
result = load_m1_feature_ladder_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["feature_set_comparison"])
display(result.tables["incremental_metric_changes"])
display(result.tables["alert_budget_comparison"])

# %%
display(result.tables["feature_availability"])
display(result.tables["rolling_origin_comparison"])
display(result.tables["unseen_player_comparison"])
display(result.tables["bootstrap_interval_comparison"])
display(result.tables["paired_bootstrap_differences"])
display(result.tables["ladder_findings"])

# %%
figures = build_m1_feature_ladder_figures(result)
for figure in figures.values():
    display(figure)
