# %% [markdown]
# # EXP-003: M1-F1 Regularised Logistic Regression
#
# Development-only evaluation of frozen absolute-load and strictly prior wellness predictors. F2/F3, post-hoc calibration selection and final-test performance remain locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_m1_f1_figures,
    load_m1_f1_config,
    load_m1_f1_from_gcp,
)

# %%
config = load_m1_f1_config(Path("../../configs/modelling/subjective_v1_m1_f1.yaml"))
settings = get_settings()
result = load_m1_f1_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["hyperparameter_results"])
display(result.tables["model_comparison"])
display(result.tables["calibration_diagnostics"])

# %%
display(result.tables["alert_budget_results"])
display(result.tables["rolling_origin_results"])
display(result.tables["unseen_player_aggregate_metrics"])
display(result.tables["bootstrap_intervals"])
display(result.tables["model_findings"])

# %%
display(result.tables["coefficient_estimates"])
display(result.tables["feature_preprocessing_context"])

# %%
figures = build_m1_f1_figures(result)
for name, figure in figures.items():
    print(name)
    display(figure)

# %% [markdown]
# ## Interpretation boundary
#
# F1 coefficients and probabilities are exploratory associations for practitioner review. They are not causal effects, diagnoses, medical thresholds or training recommendations.
