# %% [markdown]
# # EXP-016: Sparse-Predictor Availability Ablation
#
# Development-only test of whether F3's held-period advantage is carried by the availability pattern of the robust fatigue z-score rather than its value. Four arms share the frozen F3 engine: A is F3 as promoted (`DEC-043`), B removes the predictor value and its indicator, C removes the value but keeps the indicator, D is F1 as an external reference. Raw probabilities only, per `DEC-052`. Support-aware unseen-player generalisation is mandatory for every arm. Final-test performance remains locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_exp_016_figures,
    load_exp_016_config,
    load_exp_016_from_gcp,
)

# %%
config = load_exp_016_config(Path("../../configs/modelling/subjective_v1_exp_016_ablation.yaml"))
settings = get_settings()
result = load_exp_016_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["arm_pooled_metrics"])
display(result.tables["per_fold_metrics"])
display(result.tables["fixed_window_stress"])
display(result.tables["alert_budget_results"])

# %%
display(result.tables["unseen_player_aggregate_metrics"])
display(result.tables["unseen_player_gap_analysis"])
display(result.tables["paired_arm_differences"])

# %%
display(result.tables["one_day_gap_sensitivity"])
display(result.tables["predictor_contract"])
display(result.tables["ablation_findings"])

# %%
figures = build_exp_016_figures(result)
for figure in figures.values():
    display(figure)
