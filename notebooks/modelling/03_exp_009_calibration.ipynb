# %% [markdown]
# # EXP-009: M1 Calibration Comparison
#
# Development-only comparison of raw, Platt and isotonic calibration on the frozen F1 champion predictor contract (`DEC-054`), the primary evaluation, with the frozen F3 predictor contract retained as historical reference only (`DEC-057`). Calibrators are fitted fold-wise on inner cross-validated out-of-fold training probabilities and applied to disjoint held-out probabilities (`DEC-049`, `CAL-02`). Pooled rolling-origin is the headline; the one-day-gap sensitivity accompanies it (`DEC-047`, `DEC-048`). Final-test performance remains locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_exp_009_figures,
    load_exp_009_config,
    load_exp_009_from_gcp,
)

# %%
config = load_exp_009_config(Path("../../configs/modelling/subjective_v1_exp_009_calibration.yaml"))
settings = get_settings()
result = load_exp_009_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["arm_pooled_metrics"])
display(result.tables["expected_calibration_error"])
display(result.tables["per_fold_metrics"])
display(result.tables["alert_budget_results"])

# %%
display(result.tables["paired_arm_differences"])
display(result.tables["sparse_predictor_audit"])
display(result.tables["one_day_gap_sensitivity"])
display(result.tables["fixed_window_stress"])
display(result.tables["calibration_findings"])

# %%
figures = build_exp_009_figures(result)
for figure in figures.values():
    display(figure)
