# %% [markdown]
# # EXP-008: Boosted Classification Complexity Test
#
# Development-only test of whether nonlinearity and interaction structure earn their place at this sample size, against the F1 champion (`DEC-054`). `HistGradientBoostingClassifier` over F1's nine predictors, pre-registered 16-point hyperparameter grid, iteration count selected by early stopping against the fixed chronological validation partition. Raw probabilities only, per `DEC-052`. A negative result is expected and is the deliverable. Final-test performance remains locked.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_exp_008_figures,
    load_exp_008_config,
    load_exp_008_from_gcp,
)

# %%
config = load_exp_008_config(Path("../../configs/modelling/subjective_v1_exp_008_boosting.yaml"))
settings = get_settings()
result = load_exp_008_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["arm_pooled_metrics"])
display(result.tables["per_fold_metrics"])
display(result.tables["fixed_window_stress"])
display(result.tables["training_validation_gap"])
display(result.tables["alert_budget_results"])

# %%
display(result.tables["unseen_player_aggregate_metrics"])
display(result.tables["paired_boosted_vs_f1_differences"])
display(result.tables["one_day_gap_sensitivity"])

# %%
display(result.tables["hyperparameter_selection_records"])
display(result.tables["missingness_sensitivity_native_handling"])
display(result.tables["boosting_findings"])

# %%
figures = build_exp_008_figures(result)
for figure in figures.values():
    display(figure)
