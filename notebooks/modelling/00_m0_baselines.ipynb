# %% [markdown]
# # EXP-002: M0 Naive Baselines
#
# Development-only view of the global prevalence and pre-specified recent-load benchmarks. The final test is not evaluated.

# %%
from pathlib import Path

from IPython.display import display

from player_availability.config import get_settings
from player_availability.modelling import (
    build_m0_figures,
    load_m0_config,
    load_m0_from_gcp,
)

# %%
config = load_m0_config(Path("../../configs/modelling/subjective_v1_m0.yaml"))
settings = get_settings()
result = load_m0_from_gcp(
    project_id=settings.gcp.project_id,
    data_bucket=settings.gcp.data_bucket,
    config=config,
)
result.summary

# %%
display(result.tables["cohort_and_split_support"])
display(result.tables["baseline_definitions"])
display(result.tables["validation_metrics"])

# %%
display(result.tables["alert_budget_results"])
display(result.tables["bootstrap_intervals"])
display(result.tables["baseline_findings"])

# %%
figures = build_m0_figures(result)
for name, figure in figures.items():
    print(name)
    display(figure)

# %% [markdown]
# ## Interpretation boundary
#
# These outputs benchmark practitioner-review prioritisation for self-reported injury-related onset risk. They are not medical or causal thresholds.
